# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\reem6\Desktop\data6\smoke_detection_iot.csv")
print('Data\n--------------------------------------------------------------------\n',data.head(10))
print('\nData descreption\n----------------------------------------------------------------------------\n',data.describe())
# Out:
# Data
# --------------------------------------------------------------------
#     num         UTC  Temperature  Humidity  TVOC  eCO2  Raw_H2  Raw_Ethanol  \
# 0    0  1654733331       20.000     57.36     0   400   12306        18520
# 1    1  1654733332       20.015     56.67     0   400   12345        18651
# 2    2  1654733333       20.029     55.96     0   400   12374        18764
# 3    3  1654733334       20.044     55.28     0   400   12390        18849
# 4    4  1654733335       20.059     54.69     0   400   12403        18921
# 5    5  1654733336       20.073     54.12     0   400   12419        18998
# 6    6  1654733337       20.088     53.61     0   400   12432        19058
# 7    7  1654733338       20.103     53.20     0   400   12439        19114
# 8    8  1654733339       20.117     52.81     0   400   12448        19155
# 9    9  1654733340       20.132     52.46     0   400   12453        19195
#
#    Pressure  PM1   PM2  NC0    NC1   NC2  CNT  Fire_Alarm
# ...

# %%
features_no = len(data.columns)-2
print('The number of columns are: ',features_no)
# Out:
# The number of columns are:  14

# %%
data_no = data.shape[0]
print('The number of rows are: ',data_no)
# Out:
# The number of rows are:  62630

# %%
data = data.drop('UTC', axis=1)
print("Data after droping the 'UTC' coulmn\n-----------------------------------------------------------------------\n",data)
# Out:
# Data after droping the 'UTC' coulmn
# -----------------------------------------------------------------------
#           num  Temperature  Humidity  TVOC  eCO2  Raw_H2  Raw_Ethanol  \
# 0          0       20.000     57.36     0   400   12306        18520
# 1          1       20.015     56.67     0   400   12345        18651
# 2          2       20.029     55.96     0   400   12374        18764
# 3          3       20.044     55.28     0   400   12390        18849
# 4          4       20.059     54.69     0   400   12403        18921
# ...      ...          ...       ...   ...   ...     ...          ...
# 62625  62625       18.438     15.79   625   400   13723        20569
# 62626  62626       18.653     15.87   612   400   13731        20588
# 62627  62627       18.867     15.84   627   400   13725        20582
# 62628  62628       19.083     16.04   638   400   13712        20566
# 62629  62629       19.299     16.52   643   400   13696        20543
#
# ...
